# %%
# %%writefile bai2b_t1.inp
# 12
# Out:
# Overwriting bai2b_t2.inp

# %%
# %%writefile bai2b_t2.inp
# 7
# Out:
# Overwriting bai2b_t2.inp

# %%
# %%writefile bai2b_t3.inp
# -4
# Out:
# Overwriting bai2b_t3.inp

# %%
# Biên dịch chương trình
# !g++ 2b.cpp -o 2b.exe

# %%
# Test case 1
# !echo "Test case 1: Expected: Ket qua f1(12) = 24"
!2b.exe < bai2a_t2.inp

# Test case 2
# !echo "Test case 2: Expected: Ket qua f1(7) = -7"
!2b.exe < bai2b_t2.inp

# Test case 3
# !echo "Test case 3: Expected: Ket qua f1(-4) = -8"
!2b.exe < bai2b_t3.inp
# Out:
# "Test case 1: Expected: Ket qua f1(12) = 24"
# Nhap mot so nguyen: Ket qua f1(12) = 24
# "Test case 2: Expected: Ket qua f1(7) = -7"
# Nhap mot so nguyen: Ket qua f1(7) = -7
# "Test case 3: Expected: Ket qua f1(-4) = -8"
# Nhap mot so nguyen: Ket qua f1(-4) = -8
