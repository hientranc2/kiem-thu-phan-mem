# %%
# %%writefile bai2c_t3.inp
# 1
# Out:
# Writing bai2c_t3.inp

# %%
# %%writefile bai2c_t1.inp
# 8
# Out:
# Overwriting bai2c_t1.inp

# %%
# %%writefile bai2c_t2.inp
# 20
# Out:
# Overwriting bai2c_t2.inp

# %%
# !g++ 2c.cpp -o 2c.exe

# %%
# Test case 1
# !echo "Test case 1: Expected: Ket qua f2(8) = 16"
!2c.exe < bai2c_t1.inp

# Tets case 2
# !echo "Test case 2: Expected: Ket qua f2(20) = 40"
!2c.exe < bai2c_t2.inp
# Out:
# "Test case 1: Expected: Ket qua f2(8) = 16"
# Nhap mot so nguyen: Ket qua f2(8) = 16
# "Test case 2: Expected: Ket qua f2(20) = 40"
# Nhap mot so nguyen: Ket qua f2(20) = 40

# %%
# Tets case 3
# !echo "Test case 3: Expected: Ket qua f3(1) = 2"
!2c.exe < bai2c_t3.inp
# Out:
# "Test case 3: Expected: Ket qua f3(1) = 2"
# Nhap mot so nguyen: Ket qua f2(1) = 2
