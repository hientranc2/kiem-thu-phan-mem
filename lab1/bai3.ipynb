// %% [markdown]
// ## Bài 3 - Kiểm thử chương trình C++ với 7 test case

// %%
%%writefile bai3_t1.inp
0 0 0
%%writefile bai3_t2.inp
0 0 5
%%writefile bai3_t3.inp
1 2 5
%%writefile bai3_t4.inp
0 2 -8
%%writefile bai3_t5.inp
1 -2 1
%%writefile bai3_t6.inp
1 -5 4
%%writefile bai3_t7.inp
2 0 0

// %%
!g++ bai3.cpp -o bai3.exe

// %%
!echo "Test case 1: Expected: Infinite solutions."
!bai3.exe < bai3_t1.inp
!echo "Test case 2: Expected: No solution."
!bai3.exe < bai3_t2.inp
!echo "Test case 3: Expected: No solution."
!bai3.exe < bai3_t3.inp
!echo "Test case 4: Expected: The equation has 2 real solution(s): 2 -2"
!bai3.exe < bai3_t4.inp
!echo "Test case 5: Expected: The equation has 2 real solution(s): 1 -1"
!bai3.exe < bai3_t5.inp
!echo "Test case 6: Expected: The equation has 4 real solution(s): 1 -1 2 -2"
!bai3.exe < bai3_t6.inp
!echo "Test case 7: Expected: The equation has 1 real solution(s): 0"
!bai3.exe < bai3_t7.inp

// %%
!dir
