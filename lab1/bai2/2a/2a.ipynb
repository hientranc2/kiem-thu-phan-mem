# %%
# %%writefile bai2a_t1.inp
# 12
# Out:
# Overwriting bai2a_t1.inp

# %%
# %%writefile bai2a_t2.inp
# 9
# Out:
# Overwriting bai2a_t2.inp

# %%
# !g++ 2a.cpp -o 2a.exe

# %%
# Test case 1
# !echo "Test case 1: Expected: Ket qua f1(12) = 24"
!2a.exe < bai2a_t1.inp

# Test case 2
# !echo "Test case 2: Expected: Ket qua f1(9) = -9"
!2a.exe < bai2a_t2.inp
# Out:
# "Test case 1: Expected: Ket qua f1(12) = 24"
# Nhap mot so nguyen: Ket qua f1(12) = 24
# "Test case 2: Expected: Ket qua f1(9) = -9"
# Nhap mot so nguyen: Ket qua f1(9) = -9
