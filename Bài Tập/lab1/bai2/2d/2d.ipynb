# %%
# %%writefile bai2d_t1.inp
# 1
# Out:
# Writing bai2d_t1.inp

# %%
# %%writefile bai2d_t2.inp
# -1
# Out:
# Writing bai2d_t2.inp

# %%
# !g++ 2d.cpp -o 2d.exe -lm

# %%
# Test case 1
# !echo "Test case 1: Expected: Ket qua f3(1) = 2"
!2d.exe < bai2d_t1.inp

# Test case 2
# !echo "Test case 2: Expected: Ket qua f3(-1) = -2"
!2d.exe < bai2d_t2.inp
# Out:
# "Test case 1: Expected: Ket qua f3(1) = 2"
# Nhap mot so nguyen: Ket qua f3(1) = 2
# "Test case 2: Expected: Ket qua f3(-1) = -2"
# Nhap mot so nguyen: Ket qua f3(-1) = -2
