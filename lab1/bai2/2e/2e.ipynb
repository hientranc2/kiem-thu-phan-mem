# %%
# %%writefile bai2e_t1.inp
# 9 3 2
# Out:
# Overwriting bai2e_t1.inp

# %%
# %%writefile bai2e_t2.inp
# 2 10 5
# Out:
# Overwriting bai2e_t2.inp

# %%
# %%writefile bai2e_t3.inp
# 1 6 11
# Out:
# Overwriting bai2e_t3.inp

# %%
# %%writefile bai2e_t4.inp
# 8 8 3
# Out:
# Overwriting bai2e_t4.inp

# %%
# %%writefile bai2e_t5.inp
# 7 4 7
# Out:
# Overwriting bai2e_t5.inp

# %%
# %%writefile bai2e_t6.inp
# 3 5 5
# Out:
# Overwriting bai2e_t6.inp

# %%
# %%writefile bai2e_t7.inp
# 4 4 9
# Out:
# Overwriting bai2e_t7.inp

# %%
# %%writefile bai2e_t8.inp
# 6 10 6
# Out:
# Overwriting bai2e_t8.inp

# %%
# %%writefile bai2e_t9.inp
# 4 4 4
# Out:
# Overwriting bai2e_t9.inp

# %%
# !g++ 2e.cpp -o 2e.exe

# %%
# Test case 1
# !echo "Test case 1: Expected: 9"
!2e.exe < bai2e_t1.inp

# Test case 2
# !echo "Test case 2: Expected: 10"
!2e.exe < bai2e_t2.inp

# Test case 3
# !echo "Test case 3: Expected: 11"
!2e.exe < bai2e_t3.inp

# Test case 4
# !echo "Test case 4: Expected: 0"
!2e.exe < bai2e_t4.inp

# Test case 5
# !echo "Test case 5: Expected: 0"
!2e.exe < bai2e_t5.inp

# Test case 6
# !echo "Test case 6: Expected: 0"
!2e.exe < bai2e_t6.inp

# Test case 7
# !echo "Test case 7: Expected: 9"
!2e.exe < bai2e_t7.inp

# Test case 8
# !echo "Test case 8: Expected: 10"
!2e.exe < bai2e_t8.inp

# Test case 9
# !echo "Test case 9: Expected: 0"
!2e.exe < bai2e_t9.inp
# Out:
# "Test case 1: Expected: 9"
# Nhap ba so nguyen: Ket qua findMax(9, 3, 2) = 9
# "Test case 2: Expected: 10"
# Nhap ba so nguyen: Ket qua findMax(2, 10, 5) = 10
# "Test case 3: Expected: 11"
# Nhap ba so nguyen: Ket qua findMax(1, 6, 11) = 11
# "Test case 4: Expected: 0"
# Nhap ba so nguyen: Ket qua findMax(8, 8, 3) = 0
# "Test case 5: Expected: 0"
# Nhap ba so nguyen: Ket qua findMax(7, 4, 7) = 0
# "Test case 6: Expected: 0"
# Nhap ba so nguyen: Ket qua findMax(3, 5, 5) = 0
# "Test case 7: Expected: 9"
# Nhap ba so nguyen: Ket qua findMax(4, 4, 9) = 9
# "Test case 8: Expected: 10"
# Nhap ba so nguyen: Ket qua findMax(6, 10, 6) = 10
# "Test case 9: Expected: 0"
# Nhap ba so nguyen: Ket qua findMax(4, 4, 4) = 0
